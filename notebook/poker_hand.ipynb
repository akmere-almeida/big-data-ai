# %%
import pandas as pd
import numpy as np

training_df = pd.read_csv('../data/poker-hand-training.data')
testing_df = pd.read_csv('../data/poker-hand-testing.data')

# %%
col=['Suit of card #1','Rank of card #1','Suit of card #2','Rank of card #2','Suit of card #3','Rank of card #3','Suit of card #4','Rank of card #4','Suit of card #5','Rank of card 5','Poker Hand']
training_df.columns = col
testing_df.columns = col

# %%
training_df.columns
# Out:
# Index(['Suit of card #1', 'Rank of card #1', 'Suit of card #2',
#        'Rank of card #2', 'Suit of card #3', 'Rank of card #3',
#        'Suit of card #4', 'Rank of card #4', 'Suit of card #5',
#        'Rank of card 5', 'Poker Hand'],
#       dtype='object')

# %%
training_df.info
# Out:
# <bound method DataFrame.info of        Suit of card #1  Rank of card #1  Suit of card #2  Rank of card #2  \
# 0                    2               11                2               13
# 1                    3               12                3               11
# 2                    4               10                4               11
# 3                    4                1                4               13
# 4                    1                2                1                4
# ...                ...              ...              ...              ...
# 25004                3                9                2                6
# 25005                4                1                4               10
# 25006                2                1                2               10
# 25007                2               12                4                3
# 25008                1                7                3               11
#
# ...

# %%
testing_df.columns
# Out:
# Index(['Suit of card #1', 'Rank of card #1', 'Suit of card #2',
#        'Rank of card #2', 'Suit of card #3', 'Rank of card #3',
#        'Suit of card #4', 'Rank of card #4', 'Suit of card #5',
#        'Rank of card 5', 'Poker Hand'],
#       dtype='object')

# %%
testing_df.info
# Out:
# <bound method DataFrame.info of         Suit of card #1  Rank of card #1  Suit of card #2  Rank of card #2  \
# 0                     3               12                3                2
# 1                     1                9                4                6
# 2                     1                4                3               13
# 3                     3               10                2                7
# 4                     1                3                4                5
# ...                 ...              ...              ...              ...
# 999994                3                1                1               12
# 999995                3                3                4                5
# 999996                1               11                4                7
# 999997                3               11                1                8
# 999998                2                5                2                9
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
sns.heatmap(training_df.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))

sns.heatmap(testing_df.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
y_train=training_df['Poker Hand']
y_test=testing_df['Poker Hand']
# y_train=pd.get_dummies(y_train)
# y_test=pd.get_dummies(y_test)

# %%
x_train=training_df.drop('Poker Hand',axis=1)
x_test=testing_df.drop('Poker Hand',axis=1)

# %%
y_train
# Out:
# 0        9
# 1        9
# 2        9
# 3        9
# 4        8
#         ..
# 25004    0
# 25005    1
# 25006    1
# 25007    1
# 25008    1
# Name: Poker Hand, Length: 25009, dtype: int64

# %%
y_test
# Out:
# 0         1
# 1         1
# 2         1
# 3         0
# 4         0
#          ..
# 999994    1
# 999995    1
# 999996    1
# 999997    1
# 999998    2
# Name: Poker Hand, Length: 999999, dtype: int64

# %%
print('Shape of Training Set:',x_train.shape)
print('Shape of Testing Set:',x_test.shape)
# Out:
# Shape of Training Set: (25009, 10)
# Shape of Testing Set: (999999, 10)

# %%
sns.countplot(y = y_test)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Poker Hand'>

# %%
x_train.head()
# Out:
#    Suit of card #1  Rank of card #1  Suit of card #2  Rank of card #2  \
# 0                2               11                2               13
# 1                3               12                3               11
# 2                4               10                4               11
# 3                4                1                4               13
# 4                1                2                1                4
#
#    Suit of card #3  Rank of card #3  Suit of card #4  Rank of card #4  \
# 0                2               10                2               12
# 1                3               13                3               10
# 2                4                1                4               13
# 3                4               12                4               11
# 4                1                5                1                3
#
#    Suit of card #5  Rank of card 5
# 0                2               1
# 1                3               1
# ...

# %%
from imblearn.over_sampling import SVMSMOTE


from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_train=le.fit_transform(y_train)
y_test=le.transform(y_test)
# oversample = SVMSMOTE(k_neighbors=3)
# x_test,y_test=oversample.fit_resample(x_test, y_test)

sns.countplot(y = y_test)
# Out:
# <AxesSubplot:xlabel='count'>

# %%
y_train.shape
# Out:
# (25009,)

# %%
y_test.shape
# Out:
# (999999,)

# %%
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# import keras
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Activation
# from keras.optimizers import SGD
# from keras import regularizers

# model = Sequential()
# model.add(Dense(15, activation='relu', input_dim=10))
# model.add(Dense(10, activation='relu'))
# model.add(Dense(10, activation='softmax'))
# model.compile(loss='binary_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
# svc = svm.LinearSVC()
# svc.fit(x_train,y_train)
# y_pred = svc.predict(x_test)
# accuracy_score(y_pred,y_test)

# %%
# svc_model.fit(x_train, y_train)
# score = model.evaluate(x_test, y_test, batch_size=256)

# %%
# y_predict = svc_model.predict(x_test)

# %%
# accuracy_score(score,y_test)
#

# %%
# cm = confusion_matrix(y_test, score)

# %%
# sns.heatmap(score, annot = True)

# %%
# print(classification_report(y_test, score))
